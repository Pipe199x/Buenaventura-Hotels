# %%
import pandas as pd
df = pd.read_excel("../Datasets/Hotel_Maguipi.xlsx", sheet_name="Data")
df.head()
# Out:
#                                             address categories/0 categoryName  \
# 0  Maguipi, Buenaventura, Valle del Cauca, Colombia        Hotel        Hotel
# 1  Maguipi, Buenaventura, Valle del Cauca, Colombia        Hotel        Hotel
# 2  Maguipi, Buenaventura, Valle del Cauca, Colombia        Hotel        Hotel
# 3  Maguipi, Buenaventura, Valle del Cauca, Colombia        Hotel        Hotel
# 4  Maguipi, Buenaventura, Valle del Cauca, Colombia        Hotel        Hotel
#
#                     cid          city countryCode  \
# 0  14096137814823006450  Buenaventura          CO
# 1  14096137814823006450  Buenaventura          CO
# 2  14096137814823006450  Buenaventura          CO
# 3  14096137814823006450  Buenaventura          CO
# 4  14096137814823006450  Buenaventura          CO
#
#                                      fid  hotelStars  \
# 0  0x8e3724765f67c3a7:0xc39f8aa87579f0f2         NaN
# 1  0x8e3724765f67c3a7:0xc39f8aa87579f0f2         NaN
# 2  0x8e3724765f67c3a7:0xc39f8aa87579f0f2         NaN
# 3  0x8e3724765f67c3a7:0xc39f8aa87579f0f2         NaN
# 4  0x8e3724765f67c3a7:0xc39f8aa87579f0f2         NaN
#
#                                             imageUrl  isAdvertisement  ...  \
# 0  https://lh3.googleusercontent.com/p/AF1QipMm_c...            False  ...
# 1  https://lh3.googleusercontent.com/p/AF1QipMm_c...            False  ...
# 2  https://lh3.googleusercontent.com/p/AF1QipMm_c...            False  ...
# 3  https://lh3.googleusercontent.com/p/AF1QipMm_c...            False  ...
# 4  https://lh3.googleusercontent.com/p/AF1QipMm_c...            False  ...
#
#              state   street  temporarilyClosed  \
# 0  Valle del Cauca  Maguipi              False
# 1  Valle del Cauca  Maguipi              False
# 2  Valle del Cauca  Maguipi              False
# 3  Valle del Cauca  Maguipi              False
# 4  Valle del Cauca  Maguipi              False
#
#                                                 text  \
# 0  Espectacular sobre todo hagan el paseo del pla...
# 1                                                NaN
# 2  La expriencia en el hotel fue 10/10, las habit...
# 3  Un lugar increíble, la comida deliciosa, las p...
# 4  Excelente. Mejoraría un poco el menú. Pero bue...
#
#                                       textTranslated          title  \
# 0     Spectacular, especially take the planton walk.  Hotel Maguipi
# 1                                                NaN  Hotel Maguipi
# 2  The hotel experience was 10/10. The rooms are ...  Hotel Maguipi
# 3  An incredible place, delicious food, spectacul...  Hotel Maguipi
# 4  Excellent. I could improve the menu a bit. But...  Hotel Maguipi
#
#    totalScore translatedLanguage  \
# 0         4.6                 en
# 1         4.6                NaN
# 2         4.6                 en
# 3         4.6                 en
# 4         4.6                 en
#
#                                                  url visitedIn
# 0  https://www.google.com/maps/search/?api=1&quer...       NaN
# 1  https://www.google.com/maps/search/?api=1&quer...       NaN
# 2  https://www.google.com/maps/search/?api=1&quer...       NaN
# 3  https://www.google.com/maps/search/?api=1&quer...       NaN
# 4  https://www.google.com/maps/search/?api=1&quer...       NaN
#
# [5 rows x 92 columns]

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns, re, nltk
from collections import Counter
from itertools import tee
sns.set_theme(style="whitegrid", context="notebook")

PASTEL = sns.color_palette("pastel"); DEEP = sns.color_palette("deep")
MUTED  = sns.color_palette("muted"); BRIGHT = sns.color_palette("bright")
ROCKET = sns.color_palette("rocket"); FLARE  = sns.color_palette("flare")
CREST  = sns.color_palette("crest")


# Helpers para n-gramas
try: nltk.corpus.stopwords.words("spanish")
except LookupError: nltk.download("stopwords")
STOP_ES = set(nltk.corpus.stopwords.words("spanish"))
STOP = STOP_ES | {"hotel","hoteles","buenaventura"}

def clean_tokens(text: str):
    t = str(text).lower()
    t = re.sub(r"http\S+|[@#]\S+"," ", t)
    t = re.sub(r"[^a-záéíóúñü\s]", " ", t)
    return [w for w in t.split() if w not in STOP and len(w)>=3]

def top_unigrams(series: pd.Series, topn=20):
    cnt = Counter()
    for x in series.dropna(): cnt.update(clean_tokens(x))
    return pd.Series(dict(cnt.most_common(topn)))

def pairwise(it):
    a,b = tee(it); next(b, None); return zip(a,b)

def top_bigrams(series: pd.Series, topn=20):
    cnt = Counter()
    for x in series.dropna():
        toks = clean_tokens(x); cnt.update([" ".join(bg) for bg in pairwise(toks)])
    return pd.Series(dict(cnt.most_common(topn)))

# %%
# Dimensiones: filas × columnas
df.shape
# Out:
# (1550, 92)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1550 entries, 0 to 1549
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   address                           1550 non-null   object
#  1   categories/0                      1550 non-null   object
#  2   categoryName                      1550 non-null   object
#  3   cid                               1550 non-null   uint64
#  4   city                              1550 non-null   object
#  5   countryCode                       1550 non-null   object
#  6   fid                               1550 non-null   object
#  7   hotelStars                        0 non-null      float64
#  8   imageUrl                          1550 non-null   object
#  9   isAdvertisement                   1550 non-null   bool
#  10  isLocalGuide                      1550 non-null   bool
#  11  language                          1550 non-null   object
#  12  likesCount                        1550 non-null   int64
#  13  location/lat                      1550 non-null   float64
#  14  location/lng                      1550 non-null   float64
#  15  name                              1550 non-null   object
#  16  neighborhood                      0 non-null      float64
#  17  originalLanguage                  844 non-null    object
#  18  permanentlyClosed                 1550 non-null   bool
#  19  placeId                           1550 non-null   object
#  20  postalCode                        0 non-null      float64
#  21  price                             0 non-null      float64
#  22  publishAt                         1550 non-null   object
#  23  publishedAtDate                   1550 non-null   object
#  24  rating                            15 non-null     object
#  25  responseFromOwnerDate             764 non-null    object
#  26  responseFromOwnerText             764 non-null    object
#  27  reviewContext/Food & drinks       31 non-null     object
#  28  reviewContext/Hotel highlights    160 non-null    object
#  29  reviewContext/Nearby activities   18 non-null     object
#  30  reviewContext/Noteworthy details  10 non-null     object
#  31  reviewContext/Rooms               21 non-null     object
#  32  reviewContext/Safety              18 non-null     object
#  33  reviewContext/Travel group        209 non-null    object
#  34  reviewContext/Trip type           212 non-null    object
#  35  reviewContext/Walkability         23 non-null     object
#  36  reviewDetailedRating/Location     329 non-null    float64
#  37  reviewDetailedRating/Rooms        310 non-null    float64
#  38  reviewDetailedRating/Service      324 non-null    float64
#  39  reviewId                          1550 non-null   object
#  40  reviewImageUrls/0                 267 non-null    object
#  41  reviewImageUrls/1                 203 non-null    object
#  42  reviewImageUrls/2                 165 non-null    object
#  43  reviewImageUrls/3                 124 non-null    object
#  44  reviewImageUrls/4                 97 non-null     object
#  45  reviewImageUrls/5                 75 non-null     object
#  46  reviewImageUrls/6                 56 non-null     object
#  47  reviewImageUrls/7                 44 non-null     object
#  48  reviewImageUrls/8                 36 non-null     object
#  49  reviewImageUrls/9                 28 non-null     object
#  50  reviewImageUrls/10                19 non-null     object
#  51  reviewImageUrls/11                15 non-null     object
#  52  reviewImageUrls/12                14 non-null     object
#  53  reviewImageUrls/13                9 non-null      object
#  54  reviewImageUrls/14                9 non-null      object
#  55  reviewImageUrls/15                7 non-null      object
#  56  reviewImageUrls/16                7 non-null      object
#  57  reviewImageUrls/17                6 non-null      object
#  58  reviewImageUrls/18                6 non-null      object
#  59  reviewImageUrls/19                5 non-null      object
#  60  reviewImageUrls/20                4 non-null      object
#  61  reviewImageUrls/21                3 non-null      object
#  62  reviewImageUrls/22                2 non-null      object
#  63  reviewImageUrls/23                2 non-null      object
#  64  reviewImageUrls/24                2 non-null      object
#  65  reviewImageUrls/25                2 non-null      object
#  66  reviewImageUrls/26                2 non-null      object
#  67  reviewImageUrls/27                2 non-null      object
#  68  reviewImageUrls/28                2 non-null      object
#  69  reviewImageUrls/29                2 non-null      object
#  70  reviewImageUrls/30                2 non-null      object
#  71  reviewImageUrls/31                1 non-null      object
#  72  reviewOrigin                      1550 non-null   object
#  73  reviewUrl                         1550 non-null   object
#  74  reviewerId                        1535 non-null   object
#  75  reviewerNumberOfReviews           1535 non-null   float64
#  76  reviewerPhotoUrl                  1550 non-null   object
#  77  reviewerUrl                       1550 non-null   object
#  78  reviewsCount                      1550 non-null   int64
#  79  scrapedAt                         1550 non-null   object
#  80  searchString                      1550 non-null   object
#  81  stars                             1535 non-null   float64
#  82  state                             1550 non-null   object
#  83  street                            1550 non-null   object
#  84  temporarilyClosed                 1550 non-null   bool
#  85  text                              833 non-null    object
#  86  textTranslated                    805 non-null    object
#  87  title                             1550 non-null   object
#  88  totalScore                        1550 non-null   float64
#  89  translatedLanguage                816 non-null    object
#  90  url                               1550 non-null   object
#  91  visitedIn                         0 non-null      float64
# dtypes: bool(4), float64(13), int64(2), object(72), uint64(1)
# memory usage: 1.0+ MB

# %%
# (opcional) conserva copia del crudo
# df_raw = df.copy()

# 1) fechas -> UTC y filtro 2020-01-01 .. 2025-08-21
df["publishedAtDate"] = pd.to_datetime(df["publishedAtDate"], errors="coerce", utc=True)
start = pd.Timestamp("2020-01-01", tz="UTC")
end   = pd.Timestamp("2025-08-21 23:59:59.999999999", tz="UTC")
mask  = df["publishedAtDate"].between(start, end, inclusive="both")

# 2) columnas a mantener (incluye dinámicas por prefijo)
base = [
    "reviewId","placeId","title","text","publishedAtDate","stars",
    "textTranslated","originalLanguage","reviewOrigin",
    "totalScore","reviewsCount","hotelStars","price",
    "isLocalGuide","reviewerNumberOfReviews","likesCount",
    "responseFromOwnerText","responseFromOwnerDate",
    "scrapedAt","categoryName"
]
ctx = [c for c in df.columns if c.startswith("reviewContext/")]
det = [c for c in df.columns if c.startswith("reviewDetailedRating/")]
keep = [c for c in base if c in df.columns] + sorted(ctx) + sorted(det)

# 3) sobrescribe df con el resultado final
before_rows, before_cols = df.shape
df = df.loc[mask, keep].copy()

print(f"▶ filas: {before_rows} → {len(df)} | columnas: {before_cols} → {len(df.columns)}")
print("   rango de fechas:", df["publishedAtDate"].min(), "→", df["publishedAtDate"].max())
missing = [c for c in base if c not in df.columns]
if missing:
    print("⚠ faltaron en este dataset:", missing)
# Out:
# ▶ filas: 1550 → 804 | columnas: 92 → 32
#    rango de fechas: 2020-01-02 12:57:18.368000+00:00 → 2025-08-20 15:46:25.723000+00:00

# %%
# --- columnas para Sentimiento ---
sent_core = ["reviewId", "placeId", "title", "text", "publishedAtDate", "stars"]
sent_opt  = ["textTranslated", "originalLanguage", "reviewOrigin"]

# --- columnas para EDA ---
eda_base = [
    "totalScore", "reviewsCount", "hotelStars", "price",
    "isLocalGuide", "reviewerNumberOfReviews", "likesCount",
    "responseFromOwnerText", "responseFromOwnerDate",
    "scrapedAt", "categoryName"  # opcional de control
]

# --- dinámicas por prefijo (si existen en este dataset) ---
ctx_cols = [c for c in df.columns if c.startswith("reviewContext/")]
det_cols = [c for c in df.columns if c.startswith("reviewDetailedRating/")]

# construir y mantener solo las columnas que existan
sent_keep = [c for c in (sent_core + sent_opt + ctx_cols + det_cols) if c in df.columns]
eda_keep  = [c for c in (eda_base + ctx_cols + det_cols) if c in df.columns]

df_sent = df[sent_keep].copy()
df_eda  = df[eda_keep].copy()

print("df_sent:", df_sent.shape, "| faltantes en este dataset:", [c for c in (sent_core+sent_opt) if c not in df.columns])
print("df_eda :", df_eda.shape,  "| faltantes en este dataset:", [c for c in eda_base if c not in df.columns])
# Out:
# df_sent: (804, 21) | faltantes en este dataset: []
# df_eda : (804, 23) | faltantes en este dataset: []

# %%
# Detectar columnas de contexto y subratings disponibles
CTX  = [c for c in df_eda.columns if c.startswith("reviewContext/")]
DRAT = [c for c in df_eda.columns if c.startswith("reviewDetailedRating/")]

# %%
df_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 804 entries, 0 to 803
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reviewId                          804 non-null    object
#  1   placeId                           804 non-null    object
#  2   title                             804 non-null    object
#  3   text                              455 non-null    object
#  4   publishedAtDate                   804 non-null    datetime64[ns, UTC]
#  5   stars                             793 non-null    float64
#  6   textTranslated                    440 non-null    object
#  7   originalLanguage                  466 non-null    object
#  8   reviewOrigin                      804 non-null    object
#  9   reviewContext/Food & drinks       31 non-null     object
#  10  reviewContext/Hotel highlights    160 non-null    object
#  11  reviewContext/Nearby activities   18 non-null     object
#  12  reviewContext/Noteworthy details  10 non-null     object
#  13  reviewContext/Rooms               21 non-null     object
#  14  reviewContext/Safety              18 non-null     object
#  15  reviewContext/Travel group        205 non-null    object
#  16  reviewContext/Trip type           206 non-null    object
#  17  reviewContext/Walkability         23 non-null     object
#  18  reviewDetailedRating/Location     321 non-null    float64
#  19  reviewDetailedRating/Rooms        302 non-null    float64
#  20  reviewDetailedRating/Service      316 non-null    float64
# dtypes: datetime64[ns, UTC](1), float64(4), object(16)
# memory usage: 138.2+ KB

# %%
df_eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 804 entries, 0 to 803
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   totalScore                        804 non-null    float64
#  1   reviewsCount                      804 non-null    int64
#  2   hotelStars                        0 non-null      float64
#  3   price                             0 non-null      float64
#  4   isLocalGuide                      804 non-null    bool
#  5   reviewerNumberOfReviews           793 non-null    float64
#  6   likesCount                        804 non-null    int64
#  7   responseFromOwnerText             455 non-null    object
#  8   responseFromOwnerDate             455 non-null    object
#  9   scrapedAt                         804 non-null    object
#  10  categoryName                      804 non-null    object
#  11  reviewContext/Food & drinks       31 non-null     object
#  12  reviewContext/Hotel highlights    160 non-null    object
#  13  reviewContext/Nearby activities   18 non-null     object
#  14  reviewContext/Noteworthy details  10 non-null     object
#  15  reviewContext/Rooms               21 non-null     object
#  16  reviewContext/Safety              18 non-null     object
#  17  reviewContext/Travel group        205 non-null    object
#  18  reviewContext/Trip type           206 non-null    object
#  19  reviewContext/Walkability         23 non-null     object
#  20  reviewDetailedRating/Location     321 non-null    float64
#  21  reviewDetailedRating/Rooms        302 non-null    float64
#  22  reviewDetailedRating/Service      316 non-null    float64
# dtypes: bool(1), float64(7), int64(2), object(13)
# memory usage: 145.3+ KB

# %%
# Instalar librerías necesarias para realizar el taller
# %pip install -U ydata-profiling[notebook]
# Out:
# Requirement already satisfied: ydata-profiling[notebook] in d:\proyecto de grado\.venv\lib\site-packages (4.17.0)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (2.3.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (3.10.0)
# Requirement already satisfied: pydantic>=2 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (2.11.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in d:\proyecto de grado\.venv\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (0.16.4)
# Requirement already satisfied: filetype>=1.0.0 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (0.61.0)
# Requirement already satisfied: jupyter>=1.0.0 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (1.1.1)
# Requirement already satisfied: ipywidgets>=7.5.1 in d:\proyecto de grado\.venv\lib\site-packages (from ydata-profiling[notebook]) (8.1.7)
# Requirement already satisfied: PyWavelets in d:\proyecto de grado\.venv\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (1.8.0)
# Requirement already satisfied: pillow in d:\proyecto de grado\.venv\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\proyecto de grado\.venv\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[notebook]) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\proyecto de grado\.venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\proyecto de grado\.venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\proyecto de grado\.venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\proyecto de grado\.venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\proyecto de grado\.venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\proyecto de grado\.venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\proyecto de grado\.venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in d:\proyecto de grado\.venv\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling[notebook]) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in d:\proyecto de grado\.venv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\proyecto de grado\.venv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in d:\proyecto de grado\.venv\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\proyecto de grado\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\proyecto de grado\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\proyecto de grado\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\proyecto de grado\.venv\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in d:\proyecto de grado\.venv\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (1.0.1)
# Requirement already satisfied: colorama in d:\proyecto de grado\.venv\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling[notebook]) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.14.0 in d:\proyecto de grado\.venv\lib\site-packages (from typeguard<5,>=3->ydata-profiling[notebook]) (4.15.0)
# Requirement already satisfied: attrs>=19.3.0 in d:\proyecto de grado\.venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in d:\proyecto de grado\.venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (3.4.2)
# Requirement already satisfied: puremagic in d:\proyecto de grado\.venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (1.30)
# Requirement already satisfied: comm>=0.1.3 in d:\proyecto de grado\.venv\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in d:\proyecto de grado\.venv\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\proyecto de grado\.venv\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\proyecto de grado\.venv\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\proyecto de grado\.venv\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.15)
# Requirement already satisfied: decorator in d:\proyecto de grado\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.2.1)
# Requirement already satisfied: exceptiongroup in d:\proyecto de grado\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in d:\proyecto de grado\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\proyecto de grado\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\proyecto de grado\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\proyecto de grado\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.19.2)
# Requirement already satisfied: stack_data in d:\proyecto de grado\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.6.3)
# Requirement already satisfied: wcwidth in d:\proyecto de grado\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\proyecto de grado\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.5)
# Requirement already satisfied: notebook in d:\proyecto de grado\.venv\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.4.5)
# Requirement already satisfied: jupyter-console in d:\proyecto de grado\.venv\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.6.3)
# Requirement already satisfied: nbconvert in d:\proyecto de grado\.venv\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.16.6)
# Requirement already satisfied: ipykernel in d:\proyecto de grado\.venv\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.30.1)
# Requirement already satisfied: jupyterlab in d:\proyecto de grado\.venv\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (4.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\proyecto de grado\.venv\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\proyecto de grado\.venv\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\proyecto de grado\.venv\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (0.4.1)
# Requirement already satisfied: six>=1.5 in d:\proyecto de grado\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.17.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\proyecto de grado\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.16)
# Requirement already satisfied: jupyter-client>=8.0.0 in d:\proyecto de grado\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\proyecto de grado\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (5.8.1)
# Requirement already satisfied: nest-asyncio>=1.4 in d:\proyecto de grado\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in d:\proyecto de grado\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in d:\proyecto de grado\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (27.0.2)
# Requirement already satisfied: tornado>=6.2 in d:\proyecto de grado\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (4.3.8)
# Requirement already satisfied: pywin32>=300 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->ydata-profiling[notebook]) (311)
# Requirement already satisfied: async-lru>=1.0.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.2.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (80.9.0)
# Requirement already satisfied: tomli>=1.2.2 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.2.1)
# Requirement already satisfied: anyio in d:\proyecto de grado\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.10.0)
# Requirement already satisfied: httpcore==1.* in d:\proyecto de grado\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\proyecto de grado\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.0)
# Requirement already satisfied: babel>=2.10 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\proyecto de grado\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (4.25.1)
# Requirement already satisfied: sniffio>=1.1 in d:\proyecto de grado\.venv\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\proyecto de grado\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.27.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (3.3.0)
# Requirement already satisfied: rfc3339-validator in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\proyecto de grado\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.1)
# Requirement already satisfied: fqdn in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: isoduration in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.1.0)
# Requirement already satisfied: uri-template in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\proyecto de grado\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in d:\proyecto de grado\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in d:\proyecto de grado\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (6.2.0)
# Requirement already satisfied: defusedxml in d:\proyecto de grado\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\proyecto de grado\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\proyecto de grado\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in d:\proyecto de grado\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\proyecto de grado\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.1)
# Requirement already satisfied: webencodings in d:\proyecto de grado\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\proyecto de grado\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\proyecto de grado\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in d:\proyecto de grado\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in d:\proyecto de grado\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.17.1)
# Requirement already satisfied: pycparser in d:\proyecto de grado\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.22)
# Requirement already satisfied: soupsieve>1.2 in d:\proyecto de grado\.venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in d:\proyecto de grado\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\proyecto de grado\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->ydata-profiling[notebook]) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in d:\proyecto de grado\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\proyecto de grado\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.0)
# Requirement already satisfied: pure-eval in d:\proyecto de grado\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport

# df ya contiene tus columnas; se perfila tal cual
profile = ProfileReport(
    df_eda,
    title="EDA Automático – Análisis de Sentimientos",
    explorative=True
)

# Mostrar inline en Jupyter
profile.to_notebook_iframe()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 23/23 [00:00<00:00, 95.21it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-09-27 21:40:49.600172&quot; name=date&gt;&lt;title&gt;EDA Automático – Análisis de Sentimientos&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", context="notebook")

# Paletas que iremos rotando
PASTEL   = sns.color_palette("pastel")
DEEP     = sns.color_palette("deep")
MUTED    = sns.color_palette("muted")
BRIGHTS  = sns.color_palette("bright")
CREST    = sns.color_palette("crest")
ROCKET   = sns.color_palette("rocket")
FLARE    = sns.color_palette("flare")

# Lista rápida de columnas útiles detectadas
ctx_cols = [c for c in df_eda.columns if c.startswith("reviewContext/")]
det_cols = [c for c in df_eda.columns if c.startswith("reviewDetailedRating/")]

print("reviewContext/*:", ctx_cols)
print("reviewDetailedRating/*:", det_cols)
# Out:
# reviewContext/*: ['reviewContext/Food & drinks', 'reviewContext/Hotel highlights', 'reviewContext/Nearby activities', 'reviewContext/Noteworthy details', 'reviewContext/Rooms', 'reviewContext/Safety', 'reviewContext/Travel group', 'reviewContext/Trip type', 'reviewContext/Walkability']
# reviewDetailedRating/*: ['reviewDetailedRating/Location', 'reviewDetailedRating/Rooms', 'reviewDetailedRating/Service']

# %%
# %matplotlib inline

# %%
if "totalScore" in df_eda.columns:
    val = df_eda["totalScore"].dropna().iloc[0] if df_eda["totalScore"].notna().any() else np.nan
    fig, ax = plt.subplots(figsize=(4,2.5), facecolor="white")
    ax.axis("off")
    ax.text(0.02, 0.65, "Total score (Google)\n(promedio global del hotel)", fontsize=10, color="#444")
    ax.text(0.02, 0.18, f"{val:.2f}" if pd.notna(val) else "N/A", fontsize=28, weight="bold", color=FLARE[4])
    plt.show()
else:
    print("No está la columna 'totalScore' en df_eda.")

# %%
if "reviewsCount" in df_eda.columns:
    val = df_eda["reviewsCount"].dropna().iloc[0] if df_eda["reviewsCount"].notna().any() else np.nan
    fig, ax = plt.subplots(figsize=(4,2.5), facecolor="white")
    ax.axis("off")
    ax.text(0.02, 0.65, "Reviews count (Google)\n(reseñas totales del hotel)", fontsize=10, color="#444")
    ax.text(0.02, 0.18, f"{int(val):,}" if pd.notna(val) else "N/A", fontsize=28, weight="bold", color=CREST[5])
    plt.show()
else:
    print("No está la columna 'reviewsCount' en df_eda.")

# %%
col = "isLocalGuide"
if col in df_eda.columns:
    counts = df_eda[col].value_counts(dropna=False)
    labels = [str(k) for k in counts.index]
    sizes  = counts.values
    colors = PASTEL[:len(labels)]

    fig, ax = plt.subplots(figsize=(4,4))
    wedges, texts = ax.pie(sizes, labels=None, startangle=90, colors=colors, wedgeprops=dict(width=0.45))
    ax.legend(wedges, [f"{l}: {v} ({v/sizes.sum():.1%})" for l,v in zip(labels, sizes)], loc="center left", bbox_to_anchor=(1, 0.5))
    ax.set_title("¿Es Local Guide?", fontsize=12)
    plt.show()
else:
    print("No está la columna 'isLocalGuide' en df_eda.")

# %%
col = "reviewerNumberOfReviews"
if col in df_eda.columns:
    s = pd.to_numeric(df_eda[col], errors="coerce").dropna()
    fig, ax = plt.subplots(figsize=(6,3.5))
    sns.histplot(s, bins=30, ax=ax, color=DEEP[2])
    ax.set_title("Distribución: número de reseñas del revisor", fontsize=12)
    ax.set_xlabel("Cantidad de reseñas (usuario)"); ax.set_ylabel("Frecuencia")
    ax.set_yscale("linear")
    plt.show()

    # Estadísticos útiles
    desc = s.describe(percentiles=[.25,.5,.75,.9,.95]).to_frame("value")
    display(desc)
else:
    print("No está 'reviewerNumberOfReviews' en df_eda.")
# Out:
#             value
# count  793.000000
# mean    39.000000
# std     79.806015
# min      0.000000
# 25%      2.000000
# 50%     10.000000
# 75%     37.000000
# 90%     96.800000
# 95%    178.000000
# max    751.000000

# %%
col = next((c for c in ctx_cols if "Trip type" in c or "Trip" in c), None)
if col and col in df_eda.columns:
    vc = df_eda[col].dropna().astype(str)
    top = vc.value_counts().head(10)
    fig, ax = plt.subplots(figsize=(6,3.5))
    sns.barplot(x=top.values, y=top.index, ax=ax, palette=BRIGHTS)
    ax.set_title(f"Trip type (top 10) — {col}", fontsize=12)
    ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()
else:
    print("No encontré columna de Trip type en reviewContext/* (revisa ctx_cols).")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\3371877204.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top.values, y=top.index, ax=ax, palette=BRIGHTS)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\3371877204.py:6: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.barplot(x=top.values, y=top.index, ax=ax, palette=BRIGHTS)

# %%
col = next((c for c in ctx_cols if "Travel group" in c or "group" in c), None)
if col and col in df_eda.columns:
    vc = df_eda[col].dropna().astype(str).value_counts()
    # Barras (recomendado)
    fig, ax = plt.subplots(figsize=(6,3.5))
    sns.barplot(x=vc.values, y=vc.index, ax=ax, palette=MUTED)
    ax.set_title(f"Travel group (top) — {col}")
    ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()
else:
    print("No encontré columna de Travel group en reviewContext/*.")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\2948858020.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=vc.values, y=vc.index, ax=ax, palette=MUTED)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\2948858020.py:6: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.barplot(x=vc.values, y=vc.index, ax=ax, palette=MUTED)

# %%
cols = [c for c in det_cols if any(k in c.lower() for k in ["location","rooms","service"])]
if cols:
    for i, c in enumerate(cols, 1):
        fig, ax = plt.subplots(figsize=(5,3))
        s = pd.to_numeric(df_eda[c], errors="coerce")
        sns.histplot(s, bins=[1,2,3,4,5,6], discrete=True, ax=ax, color=CREST[min(i, len(CREST))-1])
        ax.set_title(f"Subrating: {c} (1–5)")
        ax.set_xlabel("Puntuación"); ax.set_xlim(1,5.1)
        plt.show()
else:
    print("No encontré subratings en reviewDetailedRating/* (Location/Rooms/Service).")

# %%
col = next((c for c in ctx_cols if "Rooms" in c), None)
if col and col in df_eda.columns:
    uni = top_unigrams(df_eda[col], topn=20)
    fig, ax = plt.subplots(figsize=(7,4))
    sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=CREST)
    ax.set_title(f"Top unigramas – {col}")
    ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()
else:
    print("No encontré columna reviewContext/Rooms.")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\3898780757.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=CREST)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\3898780757.py:5: UserWarning:
# The palette list has fewer values (6) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=CREST)

# %%
col = next((c for c in ctx_cols if "Safety" in c or "seguridad" in c.lower()), None)
if col and col in df_eda.columns:
    uni = top_unigrams(df_eda[col], topn=20)
    fig, ax = plt.subplots(figsize=(7,4))
    sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=BRIGHTS)
    ax.set_title(f"Top unigramas – {col}")
    ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()
else:
    print("No encontré columna de Safety en reviewContext/*.")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\2689821224.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=BRIGHTS)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\2689821224.py:5: UserWarning:
# The palette list has fewer values (10) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=BRIGHTS)

# %%
col = next((c for c in ctx_cols if "Walkability" in c or "walk" in c.lower()), None)
if col and col in df_eda.columns:
    uni = top_unigrams(df_eda[col], topn=20)
    fig, ax = plt.subplots(figsize=(7,4))
    sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=PASTEL)
    ax.set_title(f"Top unigramas – {col}")
    ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()
else:
    print("No encontré columna de Walkability en reviewContext/*.")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\2393310856.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=PASTEL)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\2393310856.py:5: UserWarning:
# The palette list has fewer values (10) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=uni.values, y=uni.index, ax=ax, palette=PASTEL)

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns, re, nltk
from collections import Counter
from itertools import tee
sns.set_theme(style="whitegrid", context="notebook")

PASTEL = sns.color_palette("pastel"); DEEP = sns.color_palette("deep")
MUTED  = sns.color_palette("muted"); BRIGHT = sns.color_palette("bright")
ROCKET = sns.color_palette("rocket"); FLARE  = sns.color_palette("flare")
CREST  = sns.color_palette("crest")

# Detectar columnas de contexto y subratings disponibles
CTX  = [c for c in df_eda.columns if c.startswith("reviewContext/")]
DRAT = [c for c in df_eda.columns if c.startswith("reviewDetailedRating/")]

# Helpers para n-gramas
try: nltk.corpus.stopwords.words("spanish")
except LookupError: nltk.download("stopwords")
STOP_ES = set(nltk.corpus.stopwords.words("spanish"))
STOP = STOP_ES | {"hotel","hoteles","buenaventura"}

def clean_tokens(text: str):
    t = str(text).lower()
    t = re.sub(r"http\S+|[@#]\S+"," ", t)
    t = re.sub(r"[^a-záéíóúñü\s]", " ", t)
    return [w for w in t.split() if w not in STOP and len(w)>=3]

def top_unigrams(series: pd.Series, topn=20):
    cnt = Counter()
    for x in series.dropna(): cnt.update(clean_tokens(x))
    return pd.Series(dict(cnt.most_common(topn)))

def pairwise(it):
    a,b = tee(it); next(b, None); return zip(a,b)

def top_bigrams(series: pd.Series, topn=20):
    cnt = Counter()
    for x in series.dropna():
        toks = clean_tokens(x); cnt.update([" ".join(bg) for bg in pairwise(toks)])
    return pd.Series(dict(cnt.most_common(topn)))

# %%
if "stars" in df_sent.columns:
    s = pd.to_numeric(df_sent["stars"], errors="coerce").dropna()
    fig, ax = plt.subplots(figsize=(6,3.6))
    sns.histplot(s, bins=[1,2,3,4,5,6], discrete=True, color=CREST[4], ax=ax)
    ax.set_title("Distribución de estrellas"); ax.set_xlabel("Estrellas"); ax.set_xlim(1,5.1); plt.show()

    band = pd.cut(s, bins=[0,2,3,5], labels=["1–2","3","4–5"], include_lowest=True)
    vc = band.value_counts().reindex(["1–2","3","4–5"]).fillna(0)
    fig, ax = plt.subplots(figsize=(5,3.2))
    sns.barplot(x=vc.index, y=vc.values, palette=FLARE, ax=ax)
    ax.set_title("Satisfacción agrupada"); ax.set_xlabel("Bandas"); ax.set_ylabel("Cantidad"); plt.show()
else:
    print("No está 'stars' en df_sent.")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\1239739607.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=vc.index, y=vc.values, palette=FLARE, ax=ax)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\1239739607.py:10: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.barplot(x=vc.index, y=vc.values, palette=FLARE, ax=ax)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

has_cols = {"responseFromOwnerText","responseFromOwnerDate"}
if has_cols.issubset(df_eda.columns) and "publishedAtDate" in df_sent.columns:
    # --- Tasa de respuesta ---
    tasa = (df_eda["responseFromOwnerText"].notna().mean() * 100).round(2)

    fig, ax = plt.subplots(figsize=(4.2, 2.6), facecolor="white")
    ax.axis("off")
    ax.text(0.02, 0.62, "Tasa de respuesta del hotel", fontsize=10, color="#444")
    ax.text(0.02, 0.18, f"{tasa:.2f}%", fontsize=30, weight="bold", color="#72d6a0")
    plt.show()

    # --- Delay (días): solo si hay al menos una respuesta ---
    pub  = pd.to_datetime(df_sent["publishedAtDate"], errors="coerce", utc=True)
    resp = pd.to_datetime(df_eda["responseFromOwnerDate"], errors="coerce", utc=True)

    tmp = pd.DataFrame({"publishedAtDate": pub, "responseFromOwnerDate": resp}).dropna()
    if tmp.empty:
        print("No hay respuestas del dueño registradas → no se puede calcular el tiempo de respuesta.")
    else:
        delay = (tmp["responseFromOwnerDate"] - tmp["publishedAtDate"]).dt.days
        delay = delay[delay >= 0]  # por si hay registros invertidos

        if delay.empty:
            print("No hay delays válidos (>=0 días).")
        else:
            fig, ax = plt.subplots(figsize=(5.5, 3.6))
            sns.boxplot(x=delay, color="#4C78A8", ax=ax)
            ax.set_title("Tiempo de respuesta (días)")
            ax.set_xlabel("Días")
            plt.show()
else:
    print("Faltan columnas:", (has_cols - set(df_eda.columns)) | ({"publishedAtDate"} - set(df_sent.columns)))

# %%
col = next((c for c in CTX if "Food" in c or "drinks" in c or "Comida" in c), None)
if col:
    uni = top_unigrams(df_eda[col], topn=20)
    fig, ax = plt.subplots(figsize=(7.2,4.2))
    sns.barplot(x=uni.values, y=uni.index, palette=ROCKET, ax=ax)
    ax.set_title(f"Top unigramas – {col}"); ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()

    bi = top_bigrams(df_eda[col], topn=20)
    fig, ax = plt.subplots(figsize=(7.2,4.2))
    sns.barplot(x=bi.values, y=bi.index, palette=FLARE, ax=ax)
    ax.set_title(f"Top bigramas – {col}"); ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()
else:
    print("No encontré reviewContext/Food & drinks.")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\4044649846.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=uni.values, y=uni.index, palette=ROCKET, ax=ax)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\4044649846.py:5: UserWarning:
# The palette list has fewer values (6) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=uni.values, y=uni.index, palette=ROCKET, ax=ax)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\4044649846.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bi.values, y=bi.index, palette=FLARE, ax=ax)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\4044649846.py:11: UserWarning:
# The palette list has fewer values (6) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=bi.values, y=bi.index, palette=FLARE, ax=ax)

# %%
col = next((c for c in CTX if "Nearby" in c or "activit" in c.lower()), None)
if col:
    uni = top_unigrams(df_eda[col], topn=20)
    fig, ax = plt.subplots(figsize=(7.2,4.2))
    sns.barplot(x=uni.values, y=uni.index, palette=DEEP, ax=ax)
    ax.set_title(f"Top unigramas – {col}"); ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()

    bi = top_bigrams(df_eda[col], topn=20)
    fig, ax = plt.subplots(figsize=(7.2,4.2))
    sns.barplot(x=bi.values, y=bi.index, palette=PASTEL, ax=ax)
    ax.set_title(f"Top bigramas – {col}"); ax.set_xlabel("Frecuencia"); ax.set_ylabel("")
    plt.show()
else:
    print("No encontré reviewContext/Nearby activities.")
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\1490078413.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=uni.values, y=uni.index, palette=DEEP, ax=ax)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\1490078413.py:5: UserWarning:
# The palette list has fewer values (10) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=uni.values, y=uni.index, palette=DEEP, ax=ax)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\1490078413.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bi.values, y=bi.index, palette=PASTEL, ax=ax)
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\1490078413.py:11: UserWarning:
# The palette list has fewer values (10) than needed (20) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=bi.values, y=bi.index, palette=PASTEL, ax=ax)

# %%
col = next((c for c in CTX if "Hotel highlights" in c or "highlight" in c.lower() or "Noteworthy" in c), None)
if col:
    vc = df_eda[col].dropna().astype(str).value_counts().head(15)
    display(vc.to_frame("frecuencia"))
else:
    print("No encontré reviewContext/Hotel highlights o Noteworthy details.")
# Out:
#                                                     frecuencia
# reviewContext/Hotel highlights
# Great view                                                  28
# Great view, Quiet, Kid-friendly, Great value                25
# Great view, Quiet                                           14
# Great view, Quiet, Kid-friendly                             14
# Quiet                                                       12
# Great view, Quiet, Great value                              11
# Great view, Kid-friendly, Great value                        7
# Great view, Kid-friendly                                     6
# Great view, Great value                                      6
# Great view, Romantic, Quiet, Kid-friendly, Grea...           5
# Luxury                                                       5
# Great value                                                  3
# Quiet, Great value                                           3
# Luxury, Great view, Romantic, Quiet, Kid-friend...           3
# Romantic                                                     2

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# === parámetro: cuántos meses recientes mostrar ===
LAST_N_MONTHS = 18   # pon 12 para último año, o None para todos

t = df_sent.copy()
t["publishedAtDate"] = pd.to_datetime(t["publishedAtDate"], errors="coerce", utc=True)
t = t[t["publishedAtDate"].notna()].assign(ym=lambda d: d["publishedAtDate"].dt.to_period("M"))

# agrega por mes
g = (t.groupby("ym")
       .agg(reseñas=("stars","size"), avg_stars=("stars","mean"))
       .sort_index())

# rellena meses faltantes para que la línea sea continua
full_idx = pd.period_range(g.index.min(), g.index.max(), freq="M")
g = g.reindex(full_idx)
g["reseñas"] = g["reseñas"].fillna(0).astype(int)

# suaviza el promedio (rolling 3 meses) para que se vea mejor
g["avg_stars_smooth"] = g["avg_stars"].rolling(3, min_periods=1).mean()

# recorta a últimos N meses si aplica
if LAST_N_MONTHS:
    g = g.tail(LAST_N_MONTHS)

# eje X como posiciones + etiquetas YYYY-MM
x = np.arange(len(g))
labels = [p.strftime("%Y-%m") for p in g.index]

fig, ax1 = plt.subplots(figsize=(12, 5))

# barras: # reseñas (eje izquierdo)
ax1.bar(x, g["reseñas"], color="#4C78A8", alpha=0.35, label="# Reseñas")
ax1.set_ylabel("# Reseñas", color="#4C78A8"); ax1.tick_params(axis="y", labelcolor="#4C78A8")

# línea: promedio de estrellas (eje derecho)
ax2 = ax1.twinx()
ax2.plot(x, g["avg_stars_smooth"], marker="o", lw=2, color="#F58518", label="Prom. estrellas (3M)")
ax2.set_ylabel("Promedio estrellas (1–5)", color="#F58518"); ax2.tick_params(axis="y", labelcolor="#F58518")
ax2.set_ylim(1, 5)

# etiquetas del eje X: muestra ~12 para que no se encime
ax1.set_xticks(x)
step = max(1, len(labels)//12)
ax1.set_xticklabels([lbl if i % step == 0 else "" for i,lbl in enumerate(labels)], rotation=45, ha="right")

ax1.set_title("Evolución mensual: # reseñas (barras) y promedio de estrellas (línea, suavizado 3M)")

# leyenda combinada
lines, labs = [], []
for ax in (ax1, ax2):
    L = ax.get_legend_handles_labels()
    lines += L[0]; labs += L[1]
ax1.legend(lines, labs, loc="upper left", frameon=True)

ax1.grid(True, axis="y", alpha=.3)
plt.tight_layout(); plt.show()
# Out:
# C:\Users\Horse\AppData\Local\Temp\ipykernel_4048\286417151.py:8: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   t = t[t["publishedAtDate"].notna()].assign(ym=lambda d: d["publishedAtDate"].dt.to_period("M"))
